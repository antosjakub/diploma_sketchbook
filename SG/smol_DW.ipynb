# %%
import pysgpp
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_5684/103311343.py in ?()
# ----> 1 import pysgpp
#
# ~/.local/lib/python3.13/site-packages/pysgpp-0.0.0-py3.13.egg/pysgpp/__init__.py in ?()
#       4 import sys
#       5 sys.path.append(os.path.dirname(__file__))
#       6
#       7 # import pysgpp_swig and extensions
# ----> 8 from .pysgpp_swig import *
#       9 from . import extensions
#
# ~/.local/lib/python3.13/site-packages/pysgpp-0.0.0-py3.13.egg/pysgpp/pysgpp_swig.py in ?()
#       4 # Do not make changes to this file unless you know what you are doing - modify
#       5 # the SWIG interface file instead.
#       6
#       7 from sys import version_info as _swig_python_version_info
# ----> 8 from . import _pysgpp_swig
#       9
#      10 try:
#      11     import builtins as __builtin__
#
# ...
