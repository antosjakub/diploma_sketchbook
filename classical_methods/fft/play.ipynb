# %%
import numpy as np

# %%
import fft_based

# %%
N = 64
d = 2
grid = fft_based.interior_grid(N,d)
len(grid), grid[0].shape
# Out:
# (2, (64, 1))

# %%
# u0 - eval on grid
# f - function

# %%
def u0_fun(x):
    return np.zeros((N,)*d)

def f_fun(x,t):


#u0 = u0_fun(1)
#u0.shape
# Out:
# (64, 64)

# %%
import matplotlib.pyplot as plt
plt.imshow()

# %%
T = 1
dt = 0.01
num_steps = int(T / dt)

alpha = 0.1
u_final = fft_based.solve_heat_nd(u0, f, alpha, dt, N, num_steps, d=d)
