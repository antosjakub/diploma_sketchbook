# %%
import numpy as np

# %%
u = np.load('u_4d.npy')

# %%
u.shape
# Out:
# (16, 16, 16, 16)

# %%
u2d = u[0,4]
u2d.shape
# Out:
# (16, 16)

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(u2d)
